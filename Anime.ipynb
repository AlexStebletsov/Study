# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mat

anime = pd.read_csv('anime.csv')
anime = anime.dropna()

anime.head(10)
# Out:
#                               Title      Production Episodes       Source  \
# 0                Shingeki no Kyojin      Wit Studio       25        Manga
# 1  Fullmetal Alchemist: Brotherhood           Bones       64        Manga
# 2                  Sword Art Online    A-1 Pictures       25  Light novel
# 3                     One Punch Man        Madhouse       12    Web manga
# 4             Boku no Hero Academia           Bones       13        Manga
# 5                       Tokyo Ghoul  Studio Pierrot       12        Manga
# 6                            Naruto  Studio Pierrot      220        Manga
# 7            Hunter x Hunter (2011)        Madhouse      148        Manga
# 8                  Kimetsu no Yaiba        ufotable       26        Manga
# 9       Shingeki no Kyojin Season 2      Wit Studio       12        Manga
#
#                                       Genre                   Airdate  Rating  \
# ...

# %%
anime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 989 entries, 0 to 1991
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       989 non-null    object
#  1   Production  989 non-null    object
#  2   Episodes    989 non-null    object
#  3   Source      989 non-null    object
#  4   Genre       989 non-null    object
#  5   Airdate     989 non-null    object
#  6   Rating      989 non-null    float64
#  7   Voters      989 non-null    object
#  8   Theme       989 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 77.3+ KB

# %%
anime = anime.rename(columns=str.lower)
anime.head(3)
# Out:
#                               title    production episodes       source  \
# 0                Shingeki no Kyojin    Wit Studio       25        Manga
# 1  Fullmetal Alchemist: Brotherhood         Bones       64        Manga
# 2                  Sword Art Online  A-1 Pictures       25  Light novel
#
#                                    genre                   airdate  rating  \
# 0           Action,Drama,Fantasy,Mystery  Apr 7, 2013, 01:58 (JST)    8.52
# 1  Action,Adventure,Comedy,Drama,Fantasy  Apr 5, 2009, 17:00 (JST)    9.16
# 2       Action,Adventure,Fantasy,Romance  Jul 8, 2012, 00:00 (JST)    7.20
#
#       voters                 theme
# 0  3,142,121  Military,Super Power
# 1  2,676,911              Military
# 2  2,586,628                  Game

# %%
for i in range(989):
    if (anime.iloc[i]['episodes'] == '?'):
        anime['episodes'].iloc[i] = '0'
        
        
        
anime = anime.astype({'episodes': 'float64'})

# %%
anime.describe()
# Out:
#          episodes      rating
# count  989.000000  989.000000
# mean    26.268959    7.131112
# std     35.546207    0.759961
# min      0.000000    2.960000
# 25%     12.000000    6.640000
# 50%     13.000000    7.190000
# 75%     26.000000    7.590000
# max    500.000000    9.160000

# %%
anime['title'].value_counts()
# Out:
# Shingeki no Kyojin                         1
# Shangri-La                                 1
# Wizard Barristers: Benmashi Cecil          1
# King's Raid: Ishi wo Tsugumono-tachi       1
# Lupin the Third: Mine Fujiko to Iu Onna    1
#                                           ..
# 07-Ghost                                   1
# Karneval (TV)                              1
# Princess Connect! Re:Dive                  1
# Seirei no Moribito                         1
# Burn Up Scramble                           1
# Name: title, Length: 989, dtype: int64

# %%
anime['production'].value_counts()
# Out:
# Sunrise               61
# Toei Animation        52
# Madhouse              48
# A-1 Pictures          43
# Studio Deen           39
#                       ..
# Shirogumi              1
# M.S.C                  1
# G&G Entertainment      1
# Anima&Co.              1
# Vega Entertainment     1
# Name: production, Length: 160, dtype: int64

# %%
anime['episodes'].value_counts()
# Out:
# 12.0     357
# 13.0     140
# 24.0      93
# 26.0      88
# 25.0      57
#         ...
# 109.0      1
# 16.0       1
# 175.0      1
# 146.0      1
# 192.0      1
# Name: episodes, Length: 94, dtype: int64

# %%
anime['source'].value_counts()
# Out:
# Manga           396
# Original        245
# Light novel     149
# Game            102
# Visual novel     31
# Other            25
# Web manga        13
# Novel            13
# Card game         9
# -                 6
# Name: source, dtype: int64

# %%
anime['genre'].value_counts()
# Out:
# Action,Sci-Fi                                   74
# Action,Adventure,Fantasy                        49
# Action                                          45
# Action,Fantasy                                  41
# Action,Adventure,Comedy,Fantasy                 37
#                                                 ..
# Action,Comedy,Drama,Fantasy,Supernatural         1
# Action,Girls Love,Horror,Sci-Fi,Supernatural     1
# Action,Drama,Fantasy,Mystery,Romance             1
# Action,Supernatural,Suspense                     1
# Action,Comedy,Drama,Sci-Fi,Ecchi                 1
# Name: genre, Length: 211, dtype: int64

# %%
anime['voters'].value_counts()
# Out:
# 27,681       2
# 3,142,121    1
# 52,122       1
# 54,115       1
# 53,907       1
#             ..
# 197,225      1
# 195,887      1
# 194,712      1
# 194,390      1
# 8,662        1
# Name: voters, Length: 988, dtype: int64

# %%
anime['theme'].value_counts()
# Out:
# Shounen                       89
# Super Power                   64
# Funimation                    56
# Mecha                         55
# School                        54
#                               ..
# Historical,Mecha,Military      1
# Discotek Media,Ponycan USA     1
# AnimEigo                       1
# Martial Arts,Samurai           1
# Music,Super Power              1
# Name: theme, Length: 127, dtype: int64

# %%
anime.fillna(0)
# Out:
#                                      title            production  episodes  \
# 0                       Shingeki no Kyojin            Wit Studio      25.0
# 1         Fullmetal Alchemist: Brotherhood                 Bones      64.0
# 2                         Sword Art Online          A-1 Pictures      25.0
# 3                            One Punch Man              Madhouse      12.0
# 4                    Boku no Hero Academia                 Bones      13.0
# ...                                    ...                   ...       ...
# 1982            Kagaku Ninja-tai Gatchaman  Tatsunoko Production     105.0
# 1984                            Tiger Mask        Toei Animation     105.0
# 1986  Jinzou Ningen Kikaider The Animation                 Radix      13.0
# 1989                          Brain Powerd               Sunrise      26.0
# 1991                      Burn Up Scramble           AIC Spirits      12.0
#
#            source                                  genre  \
# ...

# %%
#sns.barplot(x="production", y="episodes", data=anime[0:10])
order1 = anime[0:10].sort_values( 'episodes' ).production

sns.barplot(x = 'production' , y = "episodes" , data = anime[0:10], order = anime[0:10].sort_values( 'episodes' ).production)
# Out:
# <AxesSubplot:xlabel='production', ylabel='episodes'>

# %%
d = anime['episodes'].value_counts()
